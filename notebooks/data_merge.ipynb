# %%
import pandas as pd 
import numpy as np 
import requests
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
water = pd.read_csv(r"C:\Users\blang\Desktop\data\Water_FINAL.csv", low_memory=False)

# %%
water['Date'] = pd.to_datetime(water['Date'])

# %%
water.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Agency BiasPC CloudCover Comments Cruise Database  \
# 0           0          2143    NaN    NaN        NaN      NaN    NaN      CMC
# 1           1          2145    NaN    NaN        NaN      NaN    NaN      CMC
#
#         Date FieldActivityEventType  FieldActivityRemark FlowStage  \
# 0 2018-04-28                    NaN                  NaN       NaN
# 1 2018-04-28                    NaN                  NaN       NaN
#
#    GaugeHeight GroupCode  HUC12  Lab   Latitude Layer  Longitude  \
# 0          NaN        FB    NaN  NaN  39.480194   NaN -75.930028
# 1          NaN        FB    NaN  NaN  39.480444   NaN -75.902528
#
#    LowerPycnocline  MeasureValue Method             ModifiedDate  \
# 0              NaN        14.970    NaN  2020-04-25T17:31:58.767
# 1              NaN        20.002    NaN  2020-04-25T17:31:59.173
#
#   Other Comments Other Conditions Parameter     ParameterName_CBP  \
# ...

# %%
benthic = pd.read_csv(r"C:\Users\blang\Desktop\data\Benthic_Stream_Health.csv", low_memory=False)

# %%
benthic = benthic.rename(columns={'sample_date': 'Date'})
benthic['Date'] = pd.to_datetime(benthic['Date'])

# %%
benthic.head(2)
# Out:
#    Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# 0           0   74228_1     74228           1               napu
# 1           1   74231_1     74231           1               napu
#
#        station_id       Date  chessie_bibi rating  Latitude  Longitude  \
# 0  BNTY005.7-4176 2006-07-26     50.326099   good  41.94361  -76.71500
# 1  BNTY002.5-4176 2006-07-26     56.969635   good  41.98583  -76.72278
#
#   Data Source Group_or_Agency        HUC12               HUCNAME   FIPS STATE  \
# 0         CBP            SRBC  20501050602  Middle Bentley Creek  42015    PA
# 1         CBP            SRBC  20501050603   Lower Bentley Creek  42015    PA
#
#             COUNTY
# 0  Bradford County
# 1  Bradford County

# %%
df.set_index('Date', inplace=True)
df.sort_values(by='Date', inplace=True)

# %%
df.head(3)
# Out:
#             Unnamed: 0_x unique_id  event_id  sample_num icprb_bioregion_id  \
# Date
# 1994-05-01          5416     542_1       542           1                lnp
# 1994-05-01          5416     542_1       542           1                lnp
# 1994-05-01          5416     542_1       542           1                lnp
#
#                                                    station_id  chessie_bibi  \
# Date
# 1994-05-01  ANS.SITE 15, COUNTRYSIDE TRIBUTARY OF PAINT BR...        5.6947
# 1994-05-01  ANS.SITE 15, COUNTRYSIDE TRIBUTARY OF PAINT BR...        5.6947
# 1994-05-01  ANS.SITE 15, COUNTRYSIDE TRIBUTARY OF PAINT BR...        5.6947
#
#                rating  Latitude_x  Longitude_x Data Source Group_or_Agency  \
# Date
# 1994-05-01  very_poor    39.08736    -76.96345         CMC             ANS
# 1994-05-01  very_poor    39.08736    -76.96345         CMC             ANS
# 1994-05-01  very_poor    39.08736    -76.96345         CMC             ANS
#
# ...

# %%
frames = [benthic, water]

# %%
result = pd.concat(frames)

# %%
result.shape
# Out:
# (2716090, 86)

# %%
result.tail()
# Out:
#          Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# 2708712     2708712       NaN       NaN         NaN                NaN
# 2708713     2708713       NaN       NaN         NaN                NaN
# 2708714     2708714       NaN       NaN         NaN                NaN
# 2708715     2708715       NaN       NaN         NaN                NaN
# 2708716     2708716       NaN       NaN         NaN                NaN
#
#         station_id       Date  chessie_bibi rating  Latitude  Longitude  \
# 2708712        NaN 2016-11-08           NaN    NaN  36.90456  -76.33836
# 2708713        NaN 2016-11-08           NaN    NaN  36.90456  -76.33836
# 2708714        NaN 2016-11-08           NaN    NaN  36.90456  -76.33836
# 2708715        NaN 2016-11-08           NaN    NaN  36.90456  -76.33836
# 2708716        NaN 2016-11-08           NaN    NaN  36.90456  -76.33836
#
#         Data Source Group_or_Agency         HUC12 HUCNAME  FIPS STATE COUNTY  \
# ...

# %%
loudoun_df = result[(result['COUNTY'] == 'Loudoun County') | (result['COUNTY_'] == 'Loudoun County')]

# %%
loudoun_df
# Out:
#          Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# 1618           1618    2853_1    2853.0         1.0               blue
# 1619           1619    2854_1    2854.0         1.0               blue
# 1620           1620    2855_1    2855.0         1.0               blue
# 1621           1621    2856_1    2856.0         1.0               blue
# 1622           1622    2857_1    2857.0         1.0               blue
# ...             ...       ...       ...         ...                ...
# 2355444     2355444       NaN       NaN         NaN                NaN
# 2355445     2355445       NaN       NaN         NaN                NaN
# 2355446     2355446       NaN       NaN         NaN                NaN
# 2355447     2355447       NaN       NaN         NaN                NaN
# 2355448     2355448       NaN       NaN         NaN                NaN
#
#                             station_id       Date  chessie_bibi rating  \
# ...

# %%
values = {'excellent': 5, 'good':4, 'fair':3, 'poor':2, 'very_poor':1}
for feature in ['rating']:
    loudoun_df[feature] = loudoun_df[feature].map(values)
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
loudoun_df
# Out:
#          Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# 1618           1618    2853_1    2853.0         1.0               blue
# 1619           1619    2854_1    2854.0         1.0               blue
# 1620           1620    2855_1    2855.0         1.0               blue
# 1621           1621    2856_1    2856.0         1.0               blue
# 1622           1622    2857_1    2857.0         1.0               blue
# ...             ...       ...       ...         ...                ...
# 2355444     2355444       NaN       NaN         NaN                NaN
# 2355445     2355445       NaN       NaN         NaN                NaN
# 2355446     2355446       NaN       NaN         NaN                NaN
# 2355447     2355447       NaN       NaN         NaN                NaN
# 2355448     2355448       NaN       NaN         NaN                NaN
#
#                             station_id       Date  chessie_bibi  rating  \
# ...

# %%
loudoun_df.set_index('Date', inplace=True)
loudoun_df.sort_values(by='Date', inplace=True)
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
loudoun_df
# Out:
#             Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# Date
# 2005-07-13      671247       NaN       NaN         NaN                NaN
# 2005-07-13      667704       NaN       NaN         NaN                NaN
# 2005-07-13      667703       NaN       NaN         NaN                NaN
# 2005-07-13      667698       NaN       NaN         NaN                NaN
# 2005-07-13      667699       NaN       NaN         NaN                NaN
# ...                ...       ...       ...         ...                ...
# 2020-03-11     2353995       NaN       NaN         NaN                NaN
# 2020-03-11     2353994       NaN       NaN         NaN                NaN
# 2020-03-11     2353993       NaN       NaN         NaN                NaN
# 2020-03-11     2353999       NaN       NaN         NaN                NaN
# 2020-03-11     2354000       NaN       NaN         NaN                NaN
#
# ...

# %%
temp = loudoun_df[loudoun_df['Parameter'] == 'WTEMP']

# %%
y_mean = [np.mean(y)]*len(x)

# %%
sns.set(font_scale=1.4)
fig, ax = plt.subplots(figsize=(18,12))
plt.plot(loudoun_df[loudoun_df['Parameter'] == 'WTEMP']['MeasureValue'])
plt.xlabel("Year", labelpad=10)
plt.ylabel("Temperature", labelpad=10)
plt.title("Loudoun Water Temperature", y=1.02, fontsize=22)
# Out:
# Text(0.5, 1.02, 'Loudoun Water Temperature')

# %%
loudoun_df['rating'].value_counts()
# Out:
# 1.0    165
# 2.0    123
# 3.0      1
# Name: rating, dtype: int64

# %%
values = {'excellent': 5, 'good':4, 'fair':3, 'poor':2, 'very_poor':1}
for feature in ['rating']:
    benthic[feature] = benthic[feature].map(values)

# %%
benthic.set_index('Date', inplace=True)
benthic.sort_values(by='Date', inplace=True)

# %%
ph_mean = loudoun_df[loudoun_df['Parameter'] == 'PH']['MeasureValue'].mean()

# %%
sns.set(font_scale=1.4, style='dark')
fig, ax = plt.subplots(figsize=(18,12))
plt.plot(loudoun_df[loudoun_df['Parameter'] == 'PH']['MeasureValue'], color='magenta', marker='*')
plt.xlabel("Year", labelpad=10)
plt.ylabel("pH Value", labelpad=10)
plt.title("Loudoun pH Over Time", y=1.02, fontsize=22)
# Out:
# Text(0.5, 1.02, 'Loudoun pH Over Time')

# %%
ph_mean
# Out:
# 7.707610389610394

# %%
rap_df = result[(result['COUNTY'] == 'Rappahannock County') | (result['COUNTY_'] == 'Rappahannock County')]

# %%
rap_df
# Out:
#         Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# 4994          4994    2409_1    2409.0         1.0                lnp
# 4995          4995    2410_1    2410.0         1.0                lnp
# 4996          4996    2411_1    2411.0         1.0                lnp
# 4997          4997    2412_1    2412.0         1.0                lnp
# 4998          4998    2413_1    2413.0         1.0                lnp
# ...            ...       ...       ...         ...                ...
# 241415      241415       NaN       NaN         NaN                NaN
# 241416      241416       NaN       NaN         NaN                NaN
# 241417      241417       NaN       NaN         NaN                NaN
# 241490      241490       NaN       NaN         NaN                NaN
# 241491      241491       NaN       NaN         NaN                NaN
#
#                   station_id       Date  chessie_bibi rating  Latitude  \
# ...

# %%
rap_df['Parameter'].value_counts()
# Out:
# DO.1    8
# WC.4    4
# WT.2    4
# AT.2    4
# PH.1    4
# Name: Parameter, dtype: int64

# %%
monty_df = result[(result['COUNTY'] == 'Montgomery County') | (result['COUNTY_'] == 'Montgomery County')]

# %%
monty_df['Parameter'].value_counts()
# Out:
# WTEMP       1142
# PH          1131
# TURB_NTU    1124
# DO          1115
# TALK        1104
# TP          1096
# TSS         1088
# NH4F        1080
# TN          1062
# SALINITY    1055
# NO3F        1037
# PO4F        1029
# CHLA        1006
# PH.3          99
# AT.6          99
# CO.4          98
# WT.10         98
# WC.4          92
# AT.1           8
# DO.3           8
# DO.2           8
# PH.4           8
# WC.6           8
# CO.5           8
# ECOLI.4        8
# WT.3           6
# WT.1           2
# Name: Parameter, dtype: int64

# %%
monty_df.set_index('Date', inplace=True)
monty_df.sort_values(by='Date', inplace=True)
# Out:
# C:\Users\blang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.set(font_scale=1.4, style='dark')
fig, ax = plt.subplots(figsize=(18,12))
plt.plot(monty_df[monty_df['Parameter'] == 'PH']['MeasureValue'], color='magenta', marker='*')
plt.xlabel("Year", labelpad=10)
plt.ylabel("pH Value", labelpad=10)
plt.title("Montgomery pH Over Time", fontsize=22)
# Out:
# Text(0.5, 1.0, 'Montgomery pH Over Time')

# %%
monty_mean = monty_df[monty_df['Parameter'] == 'PH']['MeasureValue'].mean()

# %%
monty_mean
# Out:
# 7.930318302387255

# %%
sns.set(font_scale=1.4)
fig, ax = plt.subplots(figsize=(18,12))
plt.plot(monty_df[monty_df['Parameter'] == 'WTEMP']['MeasureValue'])
plt.xlabel("Year", labelpad=10)
plt.ylabel("Temperature", labelpad=10)
plt.title("Montgomery Water Temperature", y=1.02, fontsize=22)
# Out:
# Text(0.5, 1.02, 'Montgomery Water Temperature')

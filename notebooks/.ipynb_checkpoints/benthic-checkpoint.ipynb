# %%
import pandas as pd 
import numpy as np 
import requests
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
water = pd.read_csv(r"C:\Users\blang\Desktop\data\Water_FINAL.csv", low_memory=False)

# %%
water.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1 Agency BiasPC CloudCover Comments Cruise Database  \
# 0           0          2143    NaN    NaN        NaN      NaN    NaN      CMC
# 1           1          2145    NaN    NaN        NaN      NaN    NaN      CMC
# 2           2          2147    NaN    NaN        NaN      NaN    NaN      CMC
#
#          Date FieldActivityEventType  FieldActivityRemark FlowStage  \
# 0  04/28/2018                    NaN                  NaN       NaN
# 1  04/28/2018                    NaN                  NaN       NaN
# 2  04/28/2018                    NaN                  NaN       NaN
#
#    GaugeHeight GroupCode  HUC12  Lab   Latitude Layer  Longitude  \
# 0          NaN        FB    NaN  NaN  39.480194   NaN -75.930028
# 1          NaN        FB    NaN  NaN  39.480444   NaN -75.902528
# 2          NaN        FB    NaN  NaN  39.466889   NaN -75.873639
#
#    LowerPycnocline  MeasureValue Method             ModifiedDate  \
# 0              NaN        14.970    NaN  2020-04-25T17:31:58.767
# 1              NaN        20.002    NaN  2020-04-25T17:31:59.173
# 2              NaN        26.204    NaN   2020-04-25T17:31:59.36
#
#   Other Comments Other Conditions Parameter     ParameterName_CBP  \
# 0            NaN              NaN     CHL.3  ACTIVE CHLOROPHYLL-A
# 1            NaN              NaN     CHL.3  ACTIVE CHLOROPHYLL-A
# 2            NaN              NaN     CHL.3  ACTIVE CHLOROPHYLL-A
#
#     ParameterName_CMC PrecipType  PrecisionPC  Pressure Problem Program  \
# 0  Chlorophyll a;b;c         NaN          NaN       NaN       E     NaN
# 1  Chlorophyll a;b;c         NaN          NaN       NaN       E     NaN
# 2  Chlorophyll a;b;c         NaN          NaN       NaN       E     NaN
#
#   Project Qualifier Rainfall Rainfall Within 24 Hours  \
# 0     NaN       NaN      NaN                      NaN
# 1     NaN       NaN      NaN                      NaN
# 2     NaN       NaN      NaN                      NaN
#
#   Rainfall Within 48 Hours  SampleDepth  SampleId SampleReplicateType  \
# 0                      7.8          0.5       1.0                 NaN
# 1                      7.8          0.5       1.0                 NaN
# 2                      7.8          0.5       1.0                 NaN
#
#   SampleType Sea State Source Station StationCode StationName Stream Flow  \
# 0        NaN       NaN    NaN     NaN  FB.FOBBT01    FOB BT01         NaN
# 1        NaN       NaN    NaN     NaN  FB.FOBBT02    FOB BT02         NaN
# 2        NaN       NaN    NaN     NaN  FB.FOBBT03    FOB BT03         NaN
#
#       Tidal Stage TideStage TierLevel      Time  TotalDepth  Unit  \
# 0  Outgoing (Ebb)       NaN        p2  12:05:00         NaN  ug/L
# 1  Outgoing (Ebb)       NaN        p2  12:40:00         NaN  ug/L
# 2  Outgoing (Ebb)       NaN        p2  13:13:00         NaN  ug/L
#
#    UpperPycnocline Water Color Water Color Description Water Odor  \
# 0              NaN         NaN                   Muddy        NaN
# 1              NaN         NaN                   Muddy        NaN
# 2              NaN         NaN                   Muddy        NaN
#
#   Water Odor Description Water Surfaces WaveHeight  \
# 0                    NaN            NaN        NaN
# 1                    NaN            NaN        NaN
# 2                    NaN            NaN        NaN
#
#   Weather Conditions Day Before Yesterday Weather Conditions Today  \
# 0                                     NaN            Partly cloudy
# 1                                     NaN            Partly cloudy
# 2                                     NaN            Partly cloudy
#
#   Weather Conditions Yesterday WindDirection   WindSpeed state  \
# 0                          NaN             W  1-10 knots    MD
# 1                          NaN             W  1-10 knots    MD
# 2                          NaN             S  1-10 knots    MD
#
#                                   Point       HUC12_       HUCNAME_  FIPS_  \
# 0  POINT (-75.93002800000002 39.480194)  20600020206  Bohemia River  24015
# 1          POINT (-75.902528 39.480444)  20600020206  Bohemia River  24015
# 2          POINT (-75.873639 39.466889)  20600020206  Bohemia River  24015
#
#         COUNTY_ STATE_
# 0  Cecil County     MD
# 1  Cecil County     MD
# 2  Cecil County     MD

# %%
stream_health = pd.read_csv(r"C:\Users\blang\Desktop\data\Benthic_Stream_Health.csv", low_memory=False)

# %%
stream_health.head(3)
# Out:
#    Unnamed: 0 unique_id  event_id  sample_num icprb_bioregion_id  \
# 0           0   74228_1     74228           1               napu
# 1           1   74231_1     74231           1               napu
# 2           2   74233_1     74233           1               napu
#
#        station_id sample_date  chessie_bibi rating  Latitude  Longitude  \
# 0  BNTY005.7-4176   7/26/2006     50.326099   good  41.94361  -76.71500
# 1  BNTY002.5-4176   7/26/2006     56.969635   good  41.98583  -76.72278
# 2  BNTY000.4-4276   7/26/2006     53.735738   good  42.01194  -76.73139
#
#   Data Source Group_or_Agency        HUC12               HUCNAME   FIPS STATE  \
# 0         CBP            SRBC  20501050602  Middle Bentley Creek  42015    PA
# 1         CBP            SRBC  20501050603   Lower Bentley Creek  42015    PA
# 2         CBP            SRBC  20501050603   Lower Bentley Creek  36015    NY
#
#             COUNTY
# 0  Bradford County
# 1  Bradford County
# 2   Chemung County

# %%
stream_health['sample_date'].min(), stream_health['sample_date'].max()
# Out:
# ('10/1/2006', '9/9/2017')

# %%
samples = pd.read_csv(r"C:\Users\blang\Desktop\data\BenthicSamples.csv", low_memory=False)

# %%
samples.head(3)
# Out:
#              DateTime        Date      Time            StationCode  \
# 0 2016-01-03 12:00:00  01/03/2016  12:00:00  VSOS.09-PL30-Acc-ACC9
# 1 2016-01-03 12:00:00  01/03/2016  12:00:00  VSOS.09-PL30-Acc-ACC9
# 2 2016-01-03 12:00:00  01/03/2016  12:00:00  VSOS.09-PL30-Acc-ACC9
#
#         StationName                  GroupName  Latitude  Longitude  \
# 0  09-PL30-Acc-ACC9  Virginia Save Our Streams   38.8533   -77.2456
# 1  09-PL30-Acc-ACC9  Virginia Save Our Streams   38.8533   -77.2456
# 2  09-PL30-Acc-ACC9  Virginia Save Our Streams   38.8533   -77.2456
#
#    Benthic Classification Name Benthic Classification Code  Count Comments  \
# 0  Dragonflies and Damselflies                          DD      2      NaN
# 1                        Scuds                          SC      5      NaN
# 2                    Flatworms                           F      6      NaN
#
#   Active Construction Algae Color Algae Located Aquatic Veg/Decaying Matter  \
# 0                 NaN         NaN           NaN                         NaN
# 1                 NaN         NaN           NaN                         NaN
# 2                 NaN         NaN           NaN                         NaN
#
#   Area 1 Sampled Area 2 Sampled Area 3 Sampled Area 4 Sampled  \
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
#
#   Barriers To Fish Movement Bottom Type Channel Width Collection Time (Net 1)  \
# 0                       NaN       rocky           NaN                   21-89
# 1                       NaN       rocky           NaN                   21-89
# 2                       NaN       rocky           NaN                   21-89
#
#   Collection Time (Net 2) Collection Time (Net 3) Collection Time (Net 4)  \
# 0                   21-89                   21-89                     NaN
# 1                   21-89                   21-89                     NaN
# 2                   21-89                   21-89                     NaN
#
#   Cropland Define Other Bank Composition Define Other Land Use  \
# 0      NaN                           NaN                   NaN
# 1      NaN                           NaN                   NaN
# 2      NaN                           NaN                   NaN
#
#   Define Other Organism Describe the Amount and Type of Litter  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
#
#   Discharge Pipes Fields Fish Water Quality Indicators Forest  \
# 0             NaN    NaN                           NaN    NaN
# 1             NaN    NaN                           NaN    NaN
# 2             NaN    NaN                           NaN    NaN
#
#   Housing Development Indicate Current and Potential Threats  \
# 0                 NaN                                    NaN
# 1                 NaN                                    NaN
# 2                 NaN                                    NaN
#
#   Livestock Pasture Logging Mining  Number of Discharge Pipes  \
# 0               NaN     NaN    NaN                        NaN
# 1               NaN     NaN    NaN                        NaN
# 2               NaN     NaN    NaN                        NaN
#
#    Number of Squirts Odor Oil and Gas Drilling Other Land Use Percent Algae  \
# 0                NaN  NaN                  NaN            NaN           NaN
# 1                NaN  NaN                  NaN            NaN           NaN
# 2                NaN  NaN                  NaN            NaN           NaN
#
#   Percent Bare Soil Percent Boulders Percent Cobbles Percent Grass  \
# 0               NaN              NaN             NaN           NaN
# 1               NaN              NaN             NaN           NaN
# 2               NaN              NaN             NaN           NaN
#
#   Percent Gravel  Percent Other  Percent Rocks Percent Sand Percent Shrubs  \
# 0            NaN            NaN            NaN          NaN            NaN
# 1            NaN            NaN            NaN          NaN            NaN
# 2            NaN            NaN            NaN          NaN            NaN
#
#   Percent Silt Percent Trees Precipitation Sanitary Landfill Silt/Sand/Gravel  \
# 0          NaN           NaN           NaN               NaN              NaN
# 1          NaN           NaN           NaN               NaN              NaN
# 2          NaN           NaN           NaN               NaN              NaN
#
#   Snags/Logs Jabs Snags/Logs Stability of Stream Stream Bed Deposit  \
# 0             NaN        NaN                 NaN                NaN
# 1             NaN        NaN                 NaN                NaN
# 2             NaN        NaN                 NaN                NaN
#
#   Stream Channel Erosion Stream Channel Shade Stream Flow  \
# 0                    NaN                  NaN      Normal
# 1                    NaN                  NaN      Normal
# 2                    NaN                  NaN      Normal
#
#   Surface Water Appearance Trash Dump Type of Cropland Type of Mining  \
# 0                      NaN        NaN              NaN            NaN
# 1                      NaN        NaN              NaN            NaN
# 2                      NaN        NaN              NaN            NaN
#
#    Type of Pipes Urban Uses Vegetated Jabs Vegetated Weather Conditions  \
# 0            NaN        NaN            NaN       NaN                NaN
# 1            NaN        NaN            NaN       NaN                NaN
# 2            NaN        NaN            NaN       NaN                NaN
#
#   Weather Last 72 Hours
# 0          Cool and dry
# 1          Cool and dry
# 2          Cool and dry

# %%
samples.columns
# Out:
# Index(['DateTime', 'Date', 'Time', 'StationCode', 'StationName', 'GroupName',
#        'Latitude', 'Longitude', 'Benthic Classification Name',
#        'Benthic Classification Code', 'Count', 'Comments',
#        'Active Construction', 'Algae Color', 'Algae Located',
#        'Aquatic Veg/Decaying Matter', 'Area 1 Sampled', 'Area 2 Sampled',
#        'Area 3 Sampled', 'Area 4 Sampled', 'Barriers To Fish Movement',
#        'Bottom Type', 'Channel Width', 'Collection Time (Net 1)',
#        'Collection Time (Net 2)', 'Collection Time (Net 3)',
#        'Collection Time (Net 4)', 'Cropland', 'Define Other Bank Composition',
#        'Define Other Land Use', 'Define Other Organism',
#        'Describe the Amount and Type of Litter', 'Discharge Pipes', 'Fields',
#        'Fish Water Quality Indicators', 'Forest', 'Housing Development',
#        'Indicate Current and Potential Threats', 'Livestock Pasture',
#        'Logging', 'Mining', 'Number of Discharge Pipes', 'Number of Squirts',
#        'Odor', 'Oil and Gas Drilling', 'Other Land Use', 'Percent Algae',
#        'Percent Bare Soil', 'Percent Boulders', 'Percent Cobbles',
#        'Percent Grass', 'Percent Gravel', 'Percent Other', 'Percent Rocks',
#        'Percent Sand', 'Percent Shrubs', 'Percent Silt', 'Percent Trees',
#        'Precipitation', 'Sanitary Landfill', 'Silt/Sand/Gravel',
#        'Snags/Logs Jabs', 'Snags/Logs', 'Stability of Stream',
#        'Stream Bed Deposit', 'Stream Channel Erosion', 'Stream Channel Shade',
#        'Stream Flow', 'Surface Water Appearance', 'Trash Dump',
#        'Type of Cropland', 'Type of Mining', 'Type of Pipes', 'Urban Uses',
#        'Vegetated Jabs', 'Vegetated', 'Weather Conditions',
#        'Weather Last 72 Hours'],
#       dtype='object')

# %%
samples.isna().sum().sort_values(ascending = False)
# Out:
# Snags/Logs Jabs                           19477
# Vegetated Jabs                            19477
# Aquatic Veg/Decaying Matter               19477
# Snags/Logs                                19477
# Precipitation                             19475
# Area 4 Sampled                            19475
# Area 3 Sampled                            19465
# Type of Pipes                             19464
# Number of Discharge Pipes                 19459
# Number of Squirts                         19456
# Silt/Sand/Gravel                          19454
# Vegetated                                 19454
# Weather Conditions                        19452
# Discharge Pipes                           19432
# Area 2 Sampled                            19342
# Area 1 Sampled                            19214
# Define Other Bank Composition             19173
# Type of Mining                            19168
# Define Other Land Use                     18772
# Type of Cropland                          18720
# Percent Gravel                            18641
# Other Land Use                            18638
# Channel Width                             18512
# Oil and Gas Drilling                      18442
# Sanitary Landfill                         18435
# Mining                                    18386
# Trash Dump                                18296
# Logging                                   18277
# Active Construction                       18196
# Cropland                                  18152
# Percent Other                             18022
# Fields                                    17964
# Livestock Pasture                         17879
# Collection Time (Net 4)                   17762
# Urban Uses                                17389
# Indicate Current and Potential Threats    17324
# Housing Development                       17268
# Percent Bare Soil                         17241
# Percent Algae                             17236
# Percent Rocks                             17228
# Percent Silt                              17208
# Forest                                    17174
# Percent Boulders                          17153
# Define Other Organism                     17087
# Algae Located                             17051
# Stream Channel Erosion                    17016
# Percent Sand                              16937
# Percent Shrubs                            16930
# Describe the Amount and Type of Litter    16917
# Percent Cobbles                           16907
# Percent Trees                             16845
# Percent Grass                             16827
# Algae Color                               16824
# Fish Water Quality Indicators             16741
# Barriers To Fish Movement                 16735
# Stream Bed Deposit                        16720
# Stream Channel Shade                      16701
# Stability of Stream                       16672
# Odor                                      16663
# Surface Water Appearance                  16646
# Collection Time (Net 3)                   16138
# Comments                                  15701
# Stream Flow                               15305
# Collection Time (Net 2)                   11651
# Weather Last 72 Hours                      7215
# Collection Time (Net 1)                    6155
# Bottom Type                                6089
# Count                                         0
# Benthic Classification Code                   0
# Benthic Classification Name                   0
# Longitude                                     0
# Latitude                                      0
# GroupName                                     0
# StationName                                   0
# StationCode                                   0
# Time                                          0
# Date                                          0
# DateTime                                      0
# dtype: int64

# %%
water['Date'] = pd.to_datetime(water['Date'])

# %%
fig, ax = plt.subplots(figsize=(15,10))
hist = ax.hist(water['Date'], bins=300)
plt.show()

# %%
samples['DateTime'] = pd.to_datetime(samples['DateTime'])
fig, ax = plt.subplots(figsize=(15,10))
hist = ax.hist(samples['DateTime'], bins=300)
plt.show()

# %%
CMC = pd.read_excel(r"C:\Users\blang\Desktop\data\CMC_Benthic_Data.xlsx")

# %%
CMC.head(3)
# Out:
#    EVENT_ID  SAMPLE_NUMBER                                       STATION_ID  \
# 0       956              1                    ANS.Site 23, Pinehurst Branch
# 1      1570              1  ANS.Site 38, Northwest Branch at Kemp Mill Road
# 2       964              1                    ANS.Site 23, Pinehurst Branch
#
#   ICPRB_BIOREGION_ID  STRAHLER_STREAM_ORDER  G_Method          SAMPLE_DATE  \
# 0                LNP                    NaN        93  2016-01-09 00:00:00
# 1                LNP                    NaN        93  2016-01-09 00:00:00
# 2                LNP                    NaN        93  2018-01-20 00:00:00
#
#    MONTH Latitude  Longitude     FINAL_ID REPORTING_VALUE TSN_FINAL  \
# 0      1  38.9719 -77.044167  PLANARIIDAE               3     54502
# 1      1  39.0613 -77.023961  PLANARIIDAE               1     54502
# 2      1  38.9719 -77.044167  PLANARIIDAE               1     54502
#
#   TAXON_LEVEL           PHYLUM      SUBPHYLUM          CLASS SUBCLASS  \
# 0         FAM  PLATYHELMINTHES  RHABDITOPHORA  TREPAXONEMATA        0
# 1         FAM  PLATYHELMINTHES  RHABDITOPHORA  TREPAXONEMATA        0
# 2         FAM  PLATYHELMINTHES  RHABDITOPHORA  TREPAXONEMATA        0
#
#        ORDER SUBORDER       FAMILY SUBFAMILY TRIBE GENUS SPECIES ASPT BIBI_TV  \
# 0  NEOOPHORA        0  PLANARIIDAE         0     0     0       0    5       8
# 1  NEOOPHORA        0  PLANARIIDAE         0     0     0       0    5       8
# 2  NEOOPHORA        0  PLANARIIDAE         0     0     0       0    5       8
#
#   BIBI_FFG BIBI_HABIT
# 0       CG         SP
# 1       CG         SP
# 2       CG         SP

# %%
CBP = pd.read_csv(r"C:\Users\blang\Desktop\data\CBP_Benthic.csv")

# %%
CBP.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Active Construction Agency  \
# 0       41433         41433               0                  NaN   SRBC
# 1       41434         41434               1                  NaN   SRBC
# 2       41435         41435               2                  NaN   SRBC
#
#    Algae Color  Algae Located  Aquatic Veg/Decaying Matter  Area 1 Sampled  \
# 0          NaN            NaN                          NaN             NaN
# 1          NaN            NaN                          NaN             NaN
# 2          NaN            NaN                          NaN             NaN
#
#    Area 2 Sampled  Area 3 Sampled  Area 4 Sampled  Barriers To Fish Movement  \
# 0             NaN             NaN             NaN                        NaN
# 1             NaN             NaN             NaN                        NaN
# 2             NaN             NaN             NaN                        NaN
#
#    Benthic Classification Code Benthic Classification Name BioMethod  \
# 0                          NaN                Chironomidae     BE110
# 1                          NaN                  Gammaridae     BE110
# 2                          NaN               Heptageniidae     BE110
#
#    Bottom Type  Channel Width  Collection Time (Net 1)  \
# 0          NaN            NaN                      NaN
# 1          NaN            NaN                      NaN
# 2          NaN            NaN                      NaN
#
#    Collection Time (Net 2)  Collection Time (Net 3)  Collection Time (Net 4)  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
#
#    Comments  Count CountyCity  Cropland Database       Date  DateTime  \
# 0       NaN  COUNT  Lancaster       NaN      CBP  7/12/2005       NaN
# 1       NaN  COUNT  Lancaster       NaN      CBP  7/12/2005       NaN
# 2       NaN  COUNT  Lancaster       NaN      CBP  7/12/2005       NaN
#
#    Define Other Bank Composition  Define Other Land Use  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
#
#    Define Other Organism  Describe the Amount and Type of Litter  \
# 0                    NaN                                     NaN
# 1                    NaN                                     NaN
# 2                    NaN                                     NaN
#
#    Discharge Pipes  EcoRegionLevel3 EcoRegionLevel3Description  EventId  \
# 0              NaN             64.0          Northern Piedmont  90821.0
# 1              NaN             64.0          Northern Piedmont  90821.0
# 2              NaN             64.0          Northern Piedmont  90821.0
#
#       FIPS  Fields  Fish Water Quality Indicators  Forest  GMethod  GroupName  \
# 0  42071.0     NaN                            NaN     NaN     94.0        NaN
# 1  42071.0     NaN                            NaN     NaN     94.0        NaN
# 2  42071.0     NaN                            NaN     NaN     94.0        NaN
#
#           HUC12       HUC12Description       HUC8    HUC8Description  \
# 0  2.050306e+10  Little Chickies Creek  2050306.0  Lower Susquehanna
# 1  2.050306e+10  Little Chickies Creek  2050306.0  Lower Susquehanna
# 2  2.050306e+10  Little Chickies Creek  2050306.0  Lower Susquehanna
#
#    Housing Development  Indicate Current and Potential Threats  Latitude  ...  \
# 0                  NaN                                     NaN  40.07806  ...
# 1                  NaN                                     NaN  40.07806  ...
# 2                  NaN                                     NaN  40.07806  ...
#
#    Odor  Oil and Gas Drilling  Other Land Use  Percent Algae  \
# 0   NaN                   NaN             NaN            NaN
# 1   NaN                   NaN             NaN            NaN
# 2   NaN                   NaN             NaN            NaN
#
#    Percent Bare Soil  Percent Boulders  Percent Cobbles  Percent Grass  \
# 0                NaN               NaN              NaN            NaN
# 1                NaN               NaN              NaN            NaN
# 2                NaN               NaN              NaN            NaN
#
#    Percent Gravel  Percent Other  Percent Rocks  Percent Sand  Percent Shrubs  \
# 0             NaN            NaN            NaN           NaN             NaN
# 1             NaN            NaN            NaN           NaN             NaN
# 2             NaN            NaN            NaN           NaN             NaN
#
#    Percent Silt  Percent Trees  Precipitation  ReportingUnits  ReportingValue  \
# 0           NaN            NaN            NaN      PER SAMPLE            16.0
# 1           NaN            NaN            NaN      PER SAMPLE           106.0
# 2           NaN            NaN            NaN      PER SAMPLE             1.0
#
#    SampleType  Sanitary Landfill  Silt/Sand/Gravel  Snags/Logs  \
# 0          CS                NaN               NaN         NaN
# 1          CS                NaN               NaN         NaN
# 2          CS                NaN               NaN         NaN
#
#    Snags/Logs Jabs Stability of Stream  State         Station  StationCode  \
# 0              NaN                 NaN     PA  LCHQ000.4-4076          NaN
# 1              NaN                 NaN     PA  LCHQ000.4-4076          NaN
# 2              NaN                 NaN     PA  LCHQ000.4-4076          NaN
#
#    StationName  Stream Bed Deposit  Stream Channel Erosion  \
# 0          NaN                 NaN                     NaN
# 1          NaN                 NaN                     NaN
# 2          NaN                 NaN                     NaN
#
#    Stream Channel Shade Stream Flow Surface Water Appearance       TSN  \
# 0                   NaN         NaN                      NaN  127917.0
# 1                   NaN         NaN                      NaN   93745.0
# 2                   NaN         NaN                      NaN  100504.0
#
#        Time  Trash Dump  Type of Cropland  Type of Mining  Type of Pipes  \
# 0  07:00:00         NaN               NaN             NaN            NaN
# 1  07:00:00         NaN               NaN             NaN            NaN
# 2  07:00:00         NaN               NaN             NaN            NaN
#
#    Urban Uses  Vegetated Vegetated Jabs  Weather Conditions  \
# 0         NaN        NaN            NaN                 NaN
# 1         NaN        NaN            NaN                 NaN
# 2         NaN        NaN            NaN                 NaN
#
#    Weather Last 72 Hours                       Point       HUC12_  \
# 0                    NaN  POINT (-76.51083 40.07806)  20503060802
# 1                    NaN  POINT (-76.51083 40.07806)  20503060802
# 2                    NaN  POINT (-76.51083 40.07806)  20503060802
#
#                HUCNAME_  FIPS_           COUNTY_  STATE_
# 0  Little Chiques Creek  42071  Lancaster County      PA
# 1  Little Chiques Creek  42071  Lancaster County      PA
# 2  Little Chiques Creek  42071  Lancaster County      PA
#
# [3 rows x 107 columns]

# %%
CBP.isna().sum().sort_values(ascending = False)
# Out:
# Percent Other                 129671
# Discharge Pipes               129671
# Mining                        129671
# Number of Discharge Pipes     129671
# Number of Squirts             129671
#                                ...
# FIPS                               0
# EventId                            0
# EcoRegionLevel3Description         0
# EcoRegionLevel3                    0
# Unnamed: 0                         0
# Length: 107, dtype: int64

# %%
samples['DateTime'].min(), samples['DateTime'].max()
# Out:
# (Timestamp('2015-07-01 12:00:00'), Timestamp('2019-12-21 12:00:00'))
